# %% [markdown]
# <a href="https://colab.research.google.com/github/ryujiuno0323/tool_code/blob/master/%E3%83%87%E3%83%BC%E3%82%BF%E5%8F%8E%E9%9B%86%EF%BC%9Cicrawler%EF%BC%9E.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# 1.データ収集＜icrawler＞
#
# icrawler後Driveにデータ保存

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %%
# !pip install icrawler

# %%
import os
import pathlib
import glob
import re
import shutil
import pprint


shutil.rmtree(original_dir)
print(os.listdir(path_aiapp))
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-5-bea28c82e547> in <module>()
#       7
#       8
# ----> 9 shutil.rmtree(original_dir)
#      10 print(os.listdir(path_aiapp))
#
# /usr/lib/python3.6/shutil.py in rmtree(path, ignore_errors, onerror)
#     475             orig_st = os.lstat(path)
#     476         except Exception:
# --> 477             onerror(os.lstat, path, sys.exc_info())
#     478             return
#     479         try:
#
# /usr/lib/python3.6/shutil.py in rmtree(path, ignore_errors, onerror)
#     473         # lstat()/open()/fstat() trick.
#     474         try:
# --> 475             orig_st = os.lstat(path)
#     476         except Exception:
#     477             onerror(os.lstat, path, sys.exc_info())
#
# FileNotFoundError: [Errno 2] No such file or directory: '/content/drive/My Drive/aiapp/clover_data_002'

# %%
    #①icrawler 保存先path
    path_aiapp="/content/drive/My Drive/aiapp/"

    #original_dir=path_aiapp+"☆_data_0☆/"
    path_original = path_aiapp+"clover_data_002/"
    original_dir = path_original
    print ("original_dir=path_original=")
    print (original_dir)

    #②trsin&Val保存先path設定
    #base_dir=original_dir 

    #base_dir=path_aiapp+"☆_split_data_0☆/"
    #path_base= path_aiapp+"class_3_split_data_10/"
    #base_dir= path_base
    #print ("base_dir=path_base=")
    #print(base_dir)

    #③out保存先path設定
    #base_dir=path_aiapp+"☆_out_data_0☆/"
    #path_out= path_aiapp+"class_3_out_data_10/"
    #tfl_out_dir= path_out
    #print ("tfl_out_dir=path_out=")
    #print(tfl_out_dir)
# Out:
# original_dir=path_original=
# /content/drive/My Drive/aiapp/clover_data_002/

# %% [markdown]
# #icrawler保存先pathと検索keyword設定

# %%
#path_0=original_dir
#★icrawler保存先pathと検索keyword設定
# ダウンロードしたい名前をclassesに記述
#classes = ["four_leaf_clover", "three_leaf_clover","autumn_leaves"]

path_0=original_dir
print(path_0)
#保存枚数-------------------
max_num_0=1000

keyword_1="four_leaf"
keyword_2="three_Leaf"
keyword_3="autumn_leaf"

path_1=path_0+keyword_1+'/'
print(path_1)

path_2=path_0+keyword_2+'/'
print(path_2)

path_3=path_0+keyword_3+'/'
print(path_3)
# Out:
# /content/drive/My Drive/aiapp/clover_data_002/
# /content/drive/My Drive/aiapp/clover_data_002/four_leaf/
# /content/drive/My Drive/aiapp/clover_data_002/three_Leaf/
# /content/drive/My Drive/aiapp/clover_data_002/autumn_leaf/

# %% [markdown]
# # icrawlerを使いDriveにデータ保存

# %%
#★ icrawlerを使いDriveにデータ保存

from icrawler.builtin import BingImageCrawler

# path1にkeyword1の画像をmax_num_0枚取得
crawler = BingImageCrawler(storage={"root_dir":path_1})
crawler.crawl(keyword=keyword_1, max_num=max_num_0)

# path2にkeyword2の画像をmax_num_0枚取得
crawler = BingImageCrawler(storage={"root_dir":path_2})
crawler.crawl(keyword=keyword_2, max_num=max_num_0)

# path3にkeyword3の画像をmax_num_0枚取得
#crawler = BingImageCrawler(storage={"root_dir":path_3})
#crawler.crawl(keyword=keyword_3, max_num=max_num_0)
# Out:
# 2020-06-22 09:07:55,937 - INFO - icrawler.crawler - start crawling...
# 2020-06-22 09:07:55,938 - INFO - icrawler.crawler - starting 1 feeder threads...
# 2020-06-22 09:07:55,944 - INFO - icrawler.crawler - starting 1 parser threads...
# 2020-06-22 09:07:55,946 - INFO - icrawler.crawler - starting 1 downloader threads...
# 2020-06-22 09:07:56,249 - INFO - parser - parsing result page https://www.bing.com/images/async?q=four_leaf&first=0
# 2020-06-22 09:07:56,273 - INFO - downloader - skip downloading file 000001.jpg
# 2020-06-22 09:07:56,274 - INFO - downloader - skip downloading file 000002.jpg
# 2020-06-22 09:07:56,276 - INFO - downloader - skip downloading file 000003.jpg
# 2020-06-22 09:07:56,278 - INFO - downloader - skip downloading file 000004.jpg
# 2020-06-22 09:07:56,280 - INFO - downloader - skip downloading file 000005.jpg
# 2020-06-22 09:07:56,282 - INFO - downloader - skip downloading file 000006.jpg
# ...

# %%
#★icrawler(3) Driveの保存済みデータデータ数表示

path = path_0
print(path)
files = os.listdir(path)  #ファイル名とディレクトリ名の両方のリストが返る
count = len(files)  
print(count)
print(files)  

path = path_1
print(path)
files = os.listdir(path)  
count = len(files)  
print(count)
print(files) 

path = path_2
print(path)
files = os.listdir(path)  
count = len(files)  
print(count)
print(files) 
"""
path = path_3
print(path)
files = os.listdir(path)  
count = len(files)  
print(count)
print(files) 
"""
# Out:
# /content/drive/My Drive/aiapp/clover_data_002/
# 2
# ['four_leaf', 'three_Leaf']
# /content/drive/My Drive/aiapp/clover_data_002/four_leaf/
# 518
# ...
